# %%
#Librerias a usar
import pandas as pd
import psycopg2

# %%
# Conexión a la base de datos PostgreSQL
conexion = psycopg2.connect(
    host="localhost",
    port="5432",
    database="CIBERPOL",
    user="postgres",
    password="password"
)

# Leer el archivo Excel
df = pd.read_excel('codigos.xlsx')
df
# Out:
#        ZONA   SUBZONA              CANTÓN COD. DISTRITO          DISTRITO
# 0    ZONA 1    CARCHI  SAN PEDRO DE HUACA         04D01            TULCAN
# 1    ZONA 1    CARCHI              TULCAN         04D01            TULCAN
# 2    ZONA 1    CARCHI             BOLÍVAR         04D02          MONTUFAR
# 3    ZONA 1    CARCHI            MONTUFAR         04D02          MONTUFAR
# 4    ZONA 1    CARCHI              ESPEJO         04D03            ESPEJO
# ..      ...       ...                 ...           ...               ...
# 237  ZONA 9       DMQ               QUITO         17D08       LOS CHILLOS
# 238  ZONA 9       DMQ               QUITO         17D09           TUMBACO
# 239  ZONA 5    GUAYAS          EL TRIUNFO         09D16  EL TRIUNFO BUCAY
# 240  ZONA 1  IMBABURA     LAS GOLONDRINAS         10D03    TIERRA DEL SOL
# 241  ZONA 4    MANABI      MANGA DEL CURA         13D05         EL CARMEN
#
# [242 rows x 5 columns]

# %%
# Selecciona las columnas específicas a cargar
columnas_asignacion = [ 'ZONA', 'SUBZONA', 'CANTÓN', 'COD. DISTRITO', 'DISTRITO']
df = df[columnas_asignacion]

# %%
# Iterar sobre las filas del DataFrame e insertarlas en la base de datos
cursor = conexion.cursor()
for indice, fila in df.iterrows():
    # Reemplazar los NaN por None
    fila = fila.where(pd.notnull(fila), None)
    # Construir la consulta SQL
    consulta = "INSERT INTO \"Localidad\" (\"zona\", \"subzona\", \"canton\", \"cod_distrito\", \"distrito\") VALUES ( %s, %s, %s, %s, %s)"
    # Ejecutar la consulta
    cursor.execute(consulta, fila.iloc[:])

# Confirmar la transacción y cerrar la conexión
conexion.commit()
cursor.close()
conexion.close()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# ...
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
# C:\Users\USER\AppData\Local\Temp\ipykernel_18896\567168640.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cursor.execute(consulta, fila.iloc[:])
